# %% [markdown]
# # Embedding oracle text via word2vec

# %%
# Load the data using msgspec and pandas
import msgspec
import datetime
import pandas as pd
from pathlib import Path
import scipy

parquet_file = Path("../datasets/default-cards-20240405090559.parquet")

if not parquet_file.exists():
    # Define the Card object to specify the different fields
    class Card(msgspec.Struct, dict=True):
        name: str | None = None
        mana_cost: str | None = None
        set: str | None = None
        cmc: float | None = None
        power: str | None = None
        toughness: str | None = None
        colors: list[str] | None = None
        oracle_text: str | None = None
        keywords: list[str] | None = None
        type_line: str | None = None
        released_at: datetime.date | None = None
        reprint: bool | None = None
        # legalities: dict[str, str] | None = None

    # Decode json into Card objects
    with open("../data/default-cards-20240405090559.json", "rb") as json_file:
        dataset = msgspec.json.decode(json_file.read(), type=list[Card])

    # Load into to a pandas dataframe
    data = pd.DataFrame([msgspec.structs.asdict(card) for card in dataset])
    data.to_parquet(parquet_file)
else:
    data = pd.read_parquet(parquet_file)

# Remove reprints
data = data[data["reprint"] == False]
data["oracle_text_clean"] = data.apply(lambda row: row["oracle_text"].replace(row["name"], "CARDNAME") if row["oracle_text"] else None, axis=1)
data["oracle_text_clean"] = data["oracle_text_clean"].str.replace(r"[\(].*?[\)]", "", regex=True)
data["oracle_text_clean"] = data["oracle_text_clean"].str.replace("{", "mana_")
data["oracle_text_clean"] = data["oracle_text_clean"].str.replace("}", " ")
data["oracle_text_clean"] = data["oracle_text_clean"].str.replace("\n", " ")
data["oracle_text_clean"] = data["oracle_text_clean"].replace("", None)

# %%
data[data["name"] == "Fury Sliver"]
# Out:
#           name mana_cost  set  cmc power toughness colors  \
# 0  Fury Sliver    {5}{R}  tsp  6.0     3         3    [R]
#
#                                 oracle_text keywords          type_line  \
# 0  All Sliver creatures have double strike.       []  Creature — Sliver
#
#   released_at  reprint                         oracle_text_clean
# 0  2006-10-06    False  All Sliver creatures have double strike.

# %%
# https://www.geeksforgeeks.org/python-word-embedding-using-word2vec/
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize # sent_tokenize, 

data["oracle_text_tokenized"] = data["oracle_text_clean"].dropna().apply(lambda sentence: [word.lower() for word in word_tokenize(sentence)])

# data_tokenized = []
# for sentence in data["oracle_text_clean"]:
#     if sentence is None:
#         continue
#     temp = []
#     for word in word_tokenize(sentence):
#         temp.append(word.lower())
    
#     data_tokenized.append(temp)

# data_tokenized

# %%
data[["oracle_text", "oracle_text_clean", "oracle_text_tokenized"]].head(10)
# Out:
#                                           oracle_text  \
# 0            All Sliver creatures have double strike.
# 1   When Kor Outfitter enters the battlefield, you...
# 3   Flying\nWhen Siren Lookout enters the battlefi...
# 5   Paradox — Draw a card for each spell you've ca...
# 6                                                None
# 7   When Venerable Knight dies, put a +1/+1 counte...
# 9   Whenever you draw your second card each turn, ...
# 12  Kicker {R} (You may pay an additional {R} as y...
# 15  Defender (This creature can't attack.)\n{3}: D...
# 18  Reach\nWhen Whiptongue Hydra enters the battle...
#
#                                     oracle_text_clean  \
# 0            All Sliver creatures have double strike.
# 1   When CARDNAME enters the battlefield, you may ...
# 3   Flying When CARDNAME enters the battlefield, i...
# 5   Paradox — Draw a card for each spell you've ca...
# 6                                                None
# 7   When CARDNAME dies, put a +1/+1 counter on tar...
# 9   Whenever you draw your second card each turn, ...
# 12  Kicker mana_R   Flying When CARDNAME enters th...
# 15  Defender  mana_3 : Destroy CARDNAME and target...
# 18  Reach When CARDNAME enters the battlefield, de...
#
#                                 oracle_text_tokenized
# 0   [all, sliver, creatures, have, double, strike, .]
# 1   [when, cardname, enters, the, battlefield, ,, ...
# 3   [flying, when, cardname, enters, the, battlefi...
# 5   [paradox, —, draw, a, card, for, each, spell, ...
# 6                                                 NaN
# 7   [when, cardname, dies, ,, put, a, +1/+1, count...
# 9   [whenever, you, draw, your, second, card, each...
# 12  [kicker, mana_r, flying, when, cardname, enter...
# 15  [defender, mana_3, :, destroy, cardname, and, ...
# 18  [reach, when, cardname, enters, the, battlefie...

# %%
model = Word2Vec(data["oracle_text_tokenized"].dropna().to_list(), min_count=1, vector_size=100, window=5)
model.wv.key_to_index.keys()
# Out:
# dict_keys(['.', ',', 'a', 'you', 'the', 'creature', 'cardname', 'of', 'your', 'to', 'target', ':', 'card', 'control', 'battlefield', 'it', 'turn', 'or', 'and', 'that', 'whenever', 'this', 'each', 'enters', 'end', 'if', 'on', 'put', 'when', 'until', 'from', 'with', 'player', 'cards', 'may', "'s", 'damage', 'mana_t', 'an', 'flying', 'creatures', 'as', 'spell', 'cast', 'hand', 'counter', '+1/+1', 'deals', 'at', 'graveyard', 'library', 'for', 'gets', '—', 'life', 'is', 'create', 'mana', "n't", 'opponent', 'one', 'draw', 'its', 'x', 'token', 'sacrifice', 'exile', 'then', 'mana_1', 'in', 'two', 'beginning', 'any', 'mana_2', 'artifact', '1', 'gain', 'choose', 'number', 'return', 'land', 'has', 'add', 'gains', 'other', 'all', 'into', 'permanent', 'combat', 'more', 'counters', 'do', '2', 'mana_b', 'mana_r', 'ca', 'top', 'power', 'have', 'mana_g', 'equal', '•', 'mana_u', 'tapped', 'attacks', 'destroy', 'their', 'be', 'up', 'trample', 'enchanted', 'another', 'mana_w', 'get', 'step', 'haste', 'only', 'less', '``', 'untap', "''", 'three', 'under', '1/1', 'value', 'upkeep', '3', 'controls', 'cost', 'sorcery', 'owner', 'onto', 'dies', 'mana_3', 'where', 'long', 'activate', 'next', 'pay', 'becomes', 'they', 'way', 'enchant', 'copy', 'reveal', 'them', 'vigilance', 'discard', 'tokens', 'strike', 'white', 'would', 'first', 'among', 'shuffle', 'than', 'search', 'green', 'color', 'instead', 'are', 'those', 'ability', 'spells', 'nonland', 'controller', 'planeswalker', 'tap', 'instant', 'loses', 'dealt', 'blocked', 'black', 'equipped', 'attacking', 'enchantment', 'during', 'exiled', 'toughness', 'was', 'red', 'mana_c', '4', 'lands', 'by', 'additional', 'unless', 'lifelink', 'look', 'menace', 'attack', 'time', 'chosen', 'flash', 'remove', 'block', '+1/+0', 'bottom', 'random', '+2/+2', 'lose', 'type', 'permanents', 'rest', 'mana_tk', 'deathtouch', 'equip', 'four', 'play', 'opponents', 'indestructible', 'without', 'blue', 'order', '2/2', 'mana_4', 'costs', 'discards', 'types', 'basic', 'prevent', 'mana_e', 'legendary', 'treasure', 'scry', 'abilities', 'colorless', 'does', 'name', 'targets', 'reach', 'paying', 'greater', 'artifacts', 'once', 'named', 'double', 'many', 'protection', 'defender', 'untapped', 'game', '5', 'sacrifices', 'no', 'deal', 'and/or', 'five', '+2/+0', 'own', 'mana_x', 'choice', 'nontoken', 'addition', 'leaves', 'except', '+1', 'there', 'draws', '-1/-1', 'total', 'hexproof', 'base', 'roll', 'can', 'face', 'noncreature', 'able', 'though', 'spirit', '3/3', 'mana_5', 'zombie', 'spend', 'revealed', 'seven', 'phase', 'equipment', 'mills', 'casts', 'activated', 'kicked', 'cycling', 'same', 'attached', 'soldier', 'human', "'", 'defending', 'regenerate', 'were', '4/4', 'ward', 'dragon', 'die', 'players', 'warrior', 'reveals', 'aura', 'mill', 'much', 'kicker', 'food', 'triggers', 'blocks', 'charge', 'spent', 'blocking', 'new', 'plus', 'commander', 'who', "'ve", 'enter', 'flashback', 'investigate', 'source', 'colors', 'amount', '+3/+3', 'become', 'sacrificed', 'chooses', 'rather', 'second', 'had', 'pays', 'anywhere', 'goblin', 'otherwise', 'flip', 'still', 'elemental', 'creates', 'perpetually', 'attach', 'partner', 'shuffles', 'twice', '−2', '6', 'chaos', 'down', 'not', 'sticker', 'forest', '+x/+x', 'attacked', 'crew', 'remains', 'suspend', 'result', 'loyalty', 'puts', 'win', 'after', 'graveyards', 'countered', 'landfall', 'deck', 'owners', 'i', 'greatest', 'planeswalkers', 'surveil', 'oil', 'times', 'regenerated', 'exiles', '|', 'did', 'starting', 'different', 'ensues', 'ii', 'six', 'least', 'iii', 'elf', 'vampire', 'died', 'visit', 'morph', 'turned', "'re", 'convoke', 'doctor', 'ring', 'emblem', 'proliferate', 'island', 'hands', '0', '−3', 'plains', 'companion', 'entered', 'phyrexian', 'monarch', 'toxic', 'tempts', '!', 'votes', 'enchantments', 'controlled', 'fights', 'knight', 'attraction', 'six-sided', '+x/+0', 'level', 'swamp', 'x/x', 'main', '☐', '7', 'shroud', 'while', 'poison', 'saproling', 'dinosaur', 'phases', 'lost', 'sliver', 'shar ...

# %%
data["oracle_text_mean_vector"] = data["oracle_text_tokenized"].dropna().apply(model.wv.get_mean_vector)

# %%
def get_similar_cards(i: int):
    df = data["oracle_text_mean_vector"].dropna().apply(lambda vector: scipy.spatial.distance.cosine(vector, data["oracle_text_mean_vector"].iloc[i]))
    data.sort_values("distance_from_card_0").head(5)

# %%
data["distance_from_card_0"] = data["oracle_text_mean_vector"].dropna().apply(lambda vector: scipy.spatial.distance.cosine(vector, data["oracle_text_mean_vector"].iloc[0]))

data.sort_values("distance_from_card_0").head(5)
# Out:
#                      name mana_cost  set  cmc power toughness colors  \
# 0             Fury Sliver    {5}{R}  tsp  6.0     3         3    [R]
# 75459     Spitting Sliver    {4}{B}  plc  5.0     3         3    [B]
# 88835        Talon Sliver    {1}{W}  tmp  2.0     1         1    [W]
# 70732  Synchronous Sliver    {4}{U}  plc  5.0     3         3    [U]
# 17533   Two-Headed Sliver    {1}{R}  tsp  2.0     1         1    [R]
#
#                                              oracle_text keywords  \
# 0               All Sliver creatures have double strike.       []
# 75459            All Sliver creatures have first strike.       []
# 88835            All Sliver creatures have first strike.       []
# 70732               All Sliver creatures have vigilance.       []
# 17533  All Sliver creatures have menace. (They can't ...       []
#
#                type_line released_at  reprint  \
# 0      Creature — Sliver  2006-10-06    False
# 75459  Creature — Sliver  2007-02-02    False
# 88835  Creature — Sliver  1997-10-14    False
# 70732  Creature — Sliver  2007-02-02    False
# 17533  Creature — Sliver  2006-10-06    False
#
#                               oracle_text_clean  \
# 0      All Sliver creatures have double strike.
# 75459   All Sliver creatures have first strike.
# 88835   All Sliver creatures have first strike.
# 70732      All Sliver creatures have vigilance.
# 17533        All Sliver creatures have menace.
#
#                                    oracle_text_tokenized  \
# 0      [all, sliver, creatures, have, double, strike, .]
# 75459   [all, sliver, creatures, have, first, strike, .]
# 88835   [all, sliver, creatures, have, first, strike, .]
# 70732       [all, sliver, creatures, have, vigilance, .]
# 17533          [all, sliver, creatures, have, menace, .]
#
#                                  oracle_text_mean_vector  distance_from_card_0
# 0      [-0.10840225, 0.046149787, 0.00978528, 0.06053...          2.072176e-08
# 75459  [-0.1030586, 0.034527756, 0.027147273, 0.06166...          2.297700e-02
# 88835  [-0.1030586, 0.034527756, 0.027147273, 0.06166...          2.297700e-02
# 70732  [-0.10191517, 0.047366787, 0.02679268, 0.06875...          6.345471e-02
# 17533  [-0.10670858, 0.06355855, 0.030505238, 0.05853...          6.693846e-02
